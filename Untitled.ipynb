# %%
import matplotlib.pyplot as plt
x=[1,2,3]
y=[2,4,1]
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title("My first graph")
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,]
y=[2,4,1,5,2,6]
plt.plot(x,y,color='green',linestyle='dashed',linewidth=3, marker=0, markerfacecolor='blue', markersize=12)
plt.ylin(1,8)
plt,xlin(1,8)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Customizations')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 6
#       4 plt.plot(x,y,color='green',linestyle='dashed',linewidth=3, marker=0, markerfacecolor='blue', markersize=12)
#       5 plt.ylim(1,8)
# ----> 6 plt,xlim(1,8)
#       7 plt.xlabel('x-axis')
#       8 plt.ylabel('y-axis')
#
# NameError: name 'xlim' is not defined
